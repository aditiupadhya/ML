# %% [markdown]
# Bayes

# %% [markdown]
# ![image.png](attachment:ff3504ab-d5d5-479f-9c93-c271136c6f08.png)

# %% [markdown]
# * P(A)=Prior probability
# * P(B|A)=Likelihood
# * P(B)=Evidence

# %%
def bayes_theorem(prior, likelihood, evidence):
    retun (likelihood * prior) / evidence

# %% [markdown]
# Gaussian Distribution:
# ---
# * bell shaped curve, where mu=mean, sigma=standard deviation
# * used in gaussian naive bayes and kernel density estimation

# %% [markdown]
# ![image.png](attachment:c7472d8c-9a6a-46f3-a02b-bc3dbcee71e5.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu, sigma = 0,1
x=np.linspace(-4,4,100)
y=(1/(np.sqrt(2 * np.pi * sigma**2))) * np.exp(-0.5 * ((x-mu) / sigma)**2)

# %%
plt.plot(x,y)
plt.title("Gaussian Distribution")
plt.show()

# %% [markdown]
# Bernoulli Distribution :
# ---
# * checks probabilty of events
# * used for binary classification problems, spam emails

# %% [markdown]
# ![image.png](attachment:0ff78d57-4797-4b0d-b8e0-4dc79c58fbd9.png)

# %%
p =0.6
plt.bar([0,1], [1-p,p], color='blue')
plt.title("Bernoulli Distribution")
plt.xticks([0,1], labels=["0(failure)" , "1(success)"])
plt.show()

# %% [markdown]
# Binomial Distribution :
# ---
# * models the number of success in n independent bernoulli trials
# * used in logistic regression to model binary outcomes

# %% [markdown]
# ![image.png](attachment:d0e752ba-55eb-45dd-a118-c19a30cf43e7.png)

# %%
from scipy.stats import binom

# %%
n,p = 10,0.5
x = np.arange(0, n+1)
y = binom.pmf(x, n, p)
plt.bar(x, y, color="green")
plt.title("Binomial Distribution")
plt.show()

# %% [markdown]
# Poisson Distribution :
# ---
# * models the number of events in a fixed interval of time or space
# * models the count data
# * number of clicks on a website

# %% [markdown]
# ![image.png](attachment:96b4a458-9899-4819-9887-9012dd9aa26e.png)

# %%
from scipy.stats import poisson

# %%
lamda =3 
x=np.arange(0,10)
y = poisson.pmf(x,lamda)
plt.bar(x,y,color = "orange")
plt.title("Poisson Distribution")
plt.show()
